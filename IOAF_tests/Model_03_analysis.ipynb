# %%
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
from utils import setup
from indicators import  compute_indicators

# %%
#surrogate model
from utils import set_model
surrogate_model = set_model("Gowal2021Improving_R18_ddpm_100m","cifar10","Linf")

# %%
attack,model,dataloader = setup(num_samples=1,
                                n_batches=1,
                                num_steps=5,
                                step_size=4/255,
                                epsilon=8/255,
                                model="Addepalli2022Efficient_RN18",
                                dataset_name="cifar10",
                                threat_model="Linf"
                                )
ds = compute_indicators(attack,model,dataloader,surrogate_model)
ds
# Out:
# Downloading models\cifar10\Linf\Addepalli2022Efficient_RN18.pt (gdrive_id=1m5vhdzIUUKhDbsZdOG9z76Eyp6f4xe_f).
# Downloading...
# From (original): https://drive.google.com/uc?id=1m5vhdzIUUKhDbsZdOG9z76Eyp6f4xe_f
# From (redirected): https://drive.google.com/uc?id=1m5vhdzIUUKhDbsZdOG9z76Eyp6f4xe_f&confirm=t&uuid=2cf24871-116c-484d-a21f-28994402649d
# To: C:\Users\ropin\PycharmProjects\SecML_pjV3\models\cifar10\Linf\Addepalli2022Efficient_RN18.pt
# 100%|██████████| 44.8M/44.8M [00:08<00:00, 5.01MB/s]
# starting pre-processing...
# end pre-processing
#
# obtaining trackers...
# trackers obtained
#
# starting unavailable_gradients_indicator...
# end unavailable_gradients_indicator
#
# staring unstable_predictions_indicator...
# end unstable_predictions_indicator
#
# staring silent_success_indicator...
# end silent_success_indicator
#
# starting incomplete_optimization_indicator...
# end incomplete_optimization_indicator
#
# start transfer_failure_indicator..
# end transfer_failure_indicator
#
# starting unconstrained_attack_failure_indicator..
# end unconstrained_attack_failure_indicator
#
# starting Attack_fails...
# end Attack_fails
#    attack_fails  unavailable_gradients  unstable_predictions  silent_success  \
# 0           1.0                  False              0.002299           False
#
#    incomplete_optimization  transfer_failure  unconstrained_attack_failure
# 0                      1.0               0.0                           0.0

# %%
attack,model,dataloader = setup(num_samples=20,
                                n_batches=2,
                                num_steps=5,
                                step_size=4/255,
                                epsilon=8/255,
                                model="Addepalli2022Efficient_RN18",
                                dataset_name="cifar10",
                                threat_model="Linf")
ds = compute_indicators(attack,model,dataloader,surrogate_model)
ds
# Out:
# starting pre-processing...
# end pre-processing
#
# obtaining trackers...
# trackers obtained
#
# starting unavailable_gradients_indicator...
# end unavailable_gradients_indicator
#
# staring unstable_predictions_indicator...
# end unstable_predictions_indicator
#
# staring silent_success_indicator...
# end silent_success_indicator
#
# starting incomplete_optimization_indicator...
# end incomplete_optimization_indicator
#
# start transfer_failure_indicator..
# end transfer_failure_indicator
#
# starting unconstrained_attack_failure_indicator..
# end unconstrained_attack_failure_indicator
#
# starting Attack_fails...
# end Attack_fails
#    attack_fails  unavailable_gradients  unstable_predictions  silent_success  \
# 0          0.65                  False              0.004111           False
#
#    incomplete_optimization  transfer_failure  unconstrained_attack_failure
# 0                      1.0              0.15                          0.25

# %%
attack, model, dataloader = setup(num_samples=1,
                                  n_batches=1,
                                  num_steps=50,
                                  step_size=4 / 255,
                                  epsilon=8 / 255,
                                  model="Addepalli2022Efficient_RN18",
                                  dataset_name="cifar10",
                                  threat_model="Linf")
ds = compute_indicators(attack,model,dataloader,surrogate_model)
ds
# Out:
# starting pre-processing...
# end pre-processing
#
# obtaining trackers...
# trackers obtained
#
# starting unavailable_gradients_indicator...
# end unavailable_gradients_indicator
#
# staring unstable_predictions_indicator...
# end unstable_predictions_indicator
#
# staring silent_success_indicator...
# end silent_success_indicator
#
# starting incomplete_optimization_indicator...
# end incomplete_optimization_indicator
#
# start transfer_failure_indicator..
# end transfer_failure_indicator
#
# starting unconstrained_attack_failure_indicator..
# end unconstrained_attack_failure_indicator
#
# starting Attack_fails...
# end Attack_fails
#    attack_fails  unavailable_gradients  unstable_predictions  silent_success  \
# 0           1.0                  False              0.002525           False
#
#    incomplete_optimization  transfer_failure  unconstrained_attack_failure
# 0                      0.0               0.0                           0.0

# %%
attack,model,dataloader = setup(num_samples=20,
                                n_batches=2,
                                num_steps=50,
                                step_size=4/255,
                                epsilon=8/255,
                                model="Addepalli2022Efficient_RN18",
                                dataset_name="cifar10",
                                threat_model="Linf")
ds = compute_indicators(attack,model,dataloader,surrogate_model)
ds
# Out:
# starting pre-processing...
# end pre-processing
#
# obtaining trackers...
# trackers obtained
#
# starting unavailable_gradients_indicator...
# end unavailable_gradients_indicator
#
# staring unstable_predictions_indicator...
# end unstable_predictions_indicator
#
# staring silent_success_indicator...
# end silent_success_indicator
#
# starting incomplete_optimization_indicator...
# end incomplete_optimization_indicator
#
# start transfer_failure_indicator..
# end transfer_failure_indicator
#
# starting unconstrained_attack_failure_indicator..
# end unconstrained_attack_failure_indicator
#
# starting Attack_fails...
# end Attack_fails
#    attack_fails  unavailable_gradients  unstable_predictions  silent_success  \
# 0          0.65                  False              0.004182           False
#
#    incomplete_optimization  transfer_failure  unconstrained_attack_failure
# 0                      0.0              0.15                           0.0
